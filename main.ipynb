# %% [markdown]
# <a href="https://www.kaggle.com/code/rohitchrisdsouza87/ghostwriter?scriptVersionId=278945985" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <img src="https://rohitconsultants.com/imgs/ghostwriter_logo.jpg" width="1900" height="400">

# %% [markdown]
# # GhostWriter 👻
# ### Autonomous AI Content Engine for WordPress, Blogs & Beyond
#
# ---
#
# ## 🔥 What Is This Project?
# GhostWriter is an **AI-powered content engine** designed to help websites publish trend-driven, SEO-optimized content automatically—covering everything from long-form blogs to social captions, newsletters, and more.
#
# ---
#
# ## 🎯 Why It Matters
# - Creating content manually is resource-intensive, slow, and inconsistent.
# - Trends emerge fast, and opportunities to rank fade slimmer every day.
# - Many brands struggle to keep up with content at the pace that search engines expect.
# - GhostWriter flips the script by turning *idea → content → distribution* into an autonomous, continuous cycle.
#
# ---
#
# ## 🧠 How It Works
# 1. **Trend Discovery** – Scrapes Reddit, X/Twitter, YouTube, SERPs & blogs for hot topics.
# 2. **Keyword Intelligence** – Scores keywords by volume, intent & competition.
# 3. **Multi-Format Generation** – Writes blogs, social posts, email newsletters, scripts, FAQ snippets.
# 4. **Visual & Media Studio** – Creates featured images, carousels, thumbnails, infographics.
# 5. **Publishing Engine** – Directly posts to WordPress and connects to social APIs.
# 6. **Performance Loop** – Tracks ranking data, updates content automatically, adapts strategy.
#
# ---
#
# ## 🌍 Why You Should Follow This Project
# - ✨ It’s **open-end and real-world**: not a toy demo, but an engine that can scale.
# - 📚 Build by build, you’ll learn how to architect autonomous agents in a marketing context.
# - 🔍 It’s perfect for anyone into AI, content, SEO, MarTech, or automation.
# - 💡 It’s early stage. Your ideas can shape it. Your contributions matter.
#
# ---
#
# ## 🤝 What We’re Looking For
# - Engineers, data scientists, prompt designers, content strategists, UI/UX folks — all welcome.
# - If you want to **lead a module** (trend-engine, generation, publishing, tracking) let’s talk.
# - Want to just watch and learn? Great—join the journey and contribute when ready.
#
# ---
#
# ## 📅 Next Steps & Roadmap
# - Phase 1: Build core content generation pipeline.
# - Phase 2: Connect to WordPress + social APIs for publishing.
# - Phase 3: Launch performance tracking + auto-update loop.
# - Phase 4: Multi-language, multi-channel, global deployment.
#
# ---
#
# ## 📢 Get Involved
# **Reach out on LinkedIn if you want to know more:**
# [https://www.linkedin.com/in/Ro-IT](https://www.linkedin.com/in/Ro-IT)
#
# Follow this notebook to stay updated and let’s build something extraordinary together.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GROQ_API_KEY = UserSecretsClient().get_secret("GROQ_API_KEY")
    os.environ["GROQ_API_KEY"] = GROQ_API_KEY
    print("✅ Setup and authentication complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GROQ_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Setup and authentication complete.

# %%
import requests


url = "https://api.groq.com/openai/v1/chat/completions"
headers = {"Authorization": f"Bearer {GROQ_API_KEY}"}


# https://console.groq.com/docs/rate-limits
data = {
    "model": "llama-3.1-8b-instant",
    "messages": [
        {
            "role": "system",
            "content": "You are a warm, pastoral Christian writer who creates short daily reflections based on scripture."
        },
        {
            "role": "user",
            "content": (
                "Write a 160–200 word Christian devotional titled “DailyServing”. "
                "Begin with a scripture verse and reference. "
                "Then write a simple, warm reflection that connects the message of the verse to everyday life. "
                "End with one practical takeaway for the day. "
                "Keep paragraphs short and formatted cleanly for WordPress."
            )
        }
    ],
    "temperature": 0.7
}

response = requests.post(url, json=data, headers=headers)
resp = response.json()
print(response.status_code)
print(response.text)
# Out:
# 200
# {"id":"chatcmpl-679b398f-4739-42e2-9f11-7ebf0922d32c","object":"chat.completion","created":1763348023,"model":"llama-3.1-8b-instant","choices":[{"index":0,"message":{"role":"assistant","content":"**DailyServing**\n\n**\"For even the Son of Man did not come to be served, but to serve, and to give his life as a ransom for many.\"** - Mark 10:45 (NIV)\n\nAs we go about our daily routines, it's easy to get caught up in our own needs and desires. We can quickly become self-focused, thinking about what we want to accomplish and how we want to be treated. But Jesus came to challenge that mindset. He didn't come to be served, but to serve.\n\nThink about the people you interact with today - your family, friends, coworkers, and even strangers. Who can you serve with humility and love? Maybe it's running an errand for a friend, listening to a colleague who needs someone to talk to, or simply holding the door open for someone behind you.\n\n**Practical Takeaway:** Make a conscious effort today to serve someone else, even if it's just in a small way. Ask God to show you opportunities to love and serve those around you, and respond with a willing heart."},"logprobs":null,"finish_reason":"stop"}],"usage":{"queue_time":0.050067483,"prompt_tokens":112,"prompt_time":0.006974646,"completion_tokens":220,"completion_time":0.368880028,"total_tokens":332,"total_time":0.375854674},"usage_breakdown":null,"system_fingerprint":"fp_e750f72ec9","x_groq":{"id":"req_01ka7vq1fafs4rsb1v9rbzajwe"},"service_tier":"on_demand"}

# %%
# Extract content safely
if "choices" in resp:
    blog_content = resp["choices"][0]["message"]["content"]
else:
    raise Exception("Groq API error: No content generated.")

print(blog_content)
# Out:
# **DailyServing**
#
# **"For even the Son of Man did not come to be served, but to serve, and to give his life as a ransom for many."** - Mark 10:45 (NIV)
#
# As we go about our daily routines, it's easy to get caught up in our own needs and desires. We can quickly become self-focused, thinking about what we want to accomplish and how we want to be treated. But Jesus came to challenge that mindset. He didn't come to be served, but to serve.
#
# Think about the people you interact with today - your family, friends, coworkers, and even strangers. Who can you serve with humility and love? Maybe it's running an errand for a friend, listening to a colleague who needs someone to talk to, or simply holding the door open for someone behind you.
#
# **Practical Takeaway:** Make a conscious effort today to serve someone else, even if it's just in a small way. Ask God to show you opportunities to love and serve those around you, and respond with a willing heart.

# %%
try:
    WP_SITE = UserSecretsClient().get_secret("WP_SITE")
    WP_USER = UserSecretsClient().get_secret("WP_USER")
    WP_PASSWORD = UserSecretsClient().get_secret("WP_PASSWORD")
    os.environ["WP_SITE"] = WP_SITE
    os.environ["WP_USER"] = WP_USER
    os.environ["WP_PASSWORD"] = WP_PASSWORD
    print("✅ WP creds locked & loaded.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'WP_USER' and 'WP_PASSWORD' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ WP creds locked & loaded.

# %%
WP_URL = f"{WP_SITE}/wp-json/wp/v2/posts"

import requests
from requests.auth import HTTPBasicAuth

# 👇 Create a DailyServing style title
import datetime
today = datetime.date.today().strftime("%B %d, %Y")
post_title = f"DailyServing: {today}"

# 👇 Optional: wrap your content in a styled section
formatted_content = f"""
<h2>Daily Serving: {today}</h2>
<p>{blog_content}</p>
<hr>
<p><em>Posted automatically by GhostWriter AI</em></p>
"""

payload = {
    "title": post_title,
    "content": formatted_content,
    "status": "publish",      # or "draft" if you want review
}

response_wp = requests.post(
    WP_URL,
    json=payload,
    auth=HTTPBasicAuth(WP_USER, WP_PASSWORD)
)

print("WP Status:", response_wp.status_code)
print("WP Response:", response_wp.json())
# Out:
# WP Status: 201
# WP Response: {'id': 1456, 'date': '2025-11-17T02:53:47', 'date_gmt': '2025-11-17T02:53:47', 'guid': {'rendered': 'https://zeatz.in/dailyserving-november-17-2025/', 'raw': 'https://zeatz.in/dailyserving-november-17-2025/'}, 'modified': '2025-11-17T02:53:47', 'modified_gmt': '2025-11-17T02:53:47', 'password': '', 'slug': 'dailyserving-november-17-2025', 'status': 'publish', 'type': 'post', 'link': 'https://zeatz.in/dailyserving-november-17-2025/', 'title': {'raw': 'DailyServing: November 17, 2025', 'rendered': 'DailyServing: November 17, 2025'}, 'content': {'raw': '\n<h2>Daily Serving: November 17, 2025</h2>\n<p>**DailyServing**\n\n**"For even the Son of Man did not come to be served, but to serve, and to give his life as a ransom for many."** - Mark 10:45 (NIV)\n\nAs we go about our daily routines, it\'s easy to get caught up in our own needs and desires. We can quickly become self-focused, thinking about what we want to accomplish and how we want to be treated. But Jesus came to challenge that mindset. He didn\'t come to be served, but to serve.\n\nThink about the people you interact with today - your family, friends, coworkers, and even strangers. Who can you serve with humility and love? Maybe it\'s running an errand for a friend, listening to a colleague who needs someone to talk to, or simply holding the door open for someone behind you.\n\n**Practical Takeaway:** Make a conscious effort today to serve someone else, even if it\'s just in a small way. Ask God to show you opportunities to love and serve those around you, and respond with a willing heart.</p>\n<hr>\n<p><em>Posted automatically by GhostWriter AI</em></p>\n', 'rendered': '<h2>Daily Serving: November 17, 2025</h2>\n<p>**DailyServing**</p>\n<p>**&#8221;For even the Son of Man did not come to be served, but to serve, and to give his life as a ransom for many.&#8221;** &#8211; Mark 10:45 (NIV)</p>\n<p>As we go about our daily routines, it&#8217;s easy to get caught up in our own needs and desires. We can quickly become self-focused, thinking about what we want to accomplish and how we want to be treated. But Jesus came to challenge that mindset. He didn&#8217;t come to be served, but to serve.</p>\n<p>Think about the people you interact with today &#8211; your family, friends, coworkers, and even strangers. Who can you serve with humility and love? Maybe it&#8217;s running an errand for a friend, listening to a colleague who needs someone to talk to, or simply holding the door open for someone behind you.</p>\n<p>**Practical Takeaway:** Make a conscious effort today to serve someone else, even if it&#8217;s just in a small way. Ask God to show you opportunities to love and serve those around you, and respond with a willing heart.</p>\n<hr>\n<p><em>Posted automatically by GhostWriter AI</em></p>\n', 'protected': False, 'block_version': 0}, 'excerpt': {'raw': '', 'rendered': '<p>Daily Serving: November 17, 2025 **DailyServing** **&#8221;For even the Son of Man did not come to be served, but to serve, and to give his life as a ransom for many.&#8221;** &#8211; Mark 10:45 (NIV) As we go about our daily routines, it&#8217;s easy to get caught up in our own needs and desires. We [&hellip;]</p>\n', 'protected': False}, 'author': 75, 'featured_media': 0, 'comment_status': 'open', 'ping_status': 'open', 'sticky': False, 'template': '', 'format': 'standard', 'meta': {'_monsterinsights_skip_tracking': False, '_monsterinsights_sitenote_active': False, '_monsterinsights_sitenote_note': '', '_monsterinsights_sitenote_category': 0, '_jetpack_memberships_contains_paid_content': False, 'footnotes': ''}, 'categories': [1], 'tags': [], 'permalink_template': 'https://zeatz.in/%postname%/', 'generated_slug': 'dailyserving-november-17-2025', 'class_list': ['post-1456', 'post', 'type-post', 'status-publish', 'format-standard', 'hentry', 'category-uncategorized'], 'jetpack_featured_media_url': '', 'jetpack_sharing_enabled': True, 'comment_count': '0', '_links': {'self': [{'href': 'https:/ ...
